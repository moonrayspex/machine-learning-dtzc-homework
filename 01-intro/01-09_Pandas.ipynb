# %%
import pandas as pd 
import numpy as np

# %%
cols = [
    'Make', 'Model', 'Year', 'Engine Fuel Type',
    'Engine HP', 'Engine Cylinders', 'Transmission Type',
    'Driven_Wheels', 'Number of Doors', 'Market Category',
    'Vehicle Size', 'Vehicle Style', 'highway MPG',
    'city mpg', 'Popularity', 'MSRP'
]
car_df = pd.read_csv(r'https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/refs/heads/master/chapter-02-car-price/data.csv', usecols=cols)

# %%
#or if data is locla - .DataFrame(a, b)
#or organize information differently - 
# can have it as a dictionary
#review:

# %%
#head
#car_df.head(25)

#series - specify columns to use from df
car_df['Engine HP']

#add column
car_df['id'] = [1,]

#delete col
del car_df['Column']
# Out:
# 0        335.0
# 1        300.0
# 2        300.0
# 3        230.0
# 4        230.0
#          ...
# 11909    300.0
# 11910    300.0
# 11911    300.0
# 11912    300.0
# 11913    221.0
# Name: Engine HP, Length: 11914, dtype: float64

# %%
#index
df = car_df
df.index
df.Make.index
# Out:
# RangeIndex(start=0, stop=11914, step=1)

# %%
#location (if single, only single [])
df.loc[[1,2]]
# Out:
#   Make     Model  Year             Engine Fuel Type  Engine HP  \
# 1  BMW  1 Series  2011  premium unleaded (required)      300.0
# 2  BMW  1 Series  2011  premium unleaded (required)      300.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
#
#            Market Category Vehicle Size Vehicle Style  highway MPG  city mpg  \
# 1       Luxury,Performance      Compact   Convertible           28        19
# 2  Luxury,High-Performance      Compact         Coupe           28        20
#
#    Popularity   MSRP
# 1        3916  40650
# 2        3916  36350

# %%
#replace index
df.index = [>indicate values for index<]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 #replace index
# ----> 2 df.index = [array]
#
# NameError: name 'array' is not defined

# %%
#reset index
df.reset_index()
#df.reset_index(drop=True) 
#reassign with original variable to overwrite
# Out:
#        index     Make       Model  Year                Engine Fuel Type  \
# 0          0      BMW  1 Series M  2011     premium unleaded (required)
# 1          1      BMW    1 Series  2011     premium unleaded (required)
# 2          2      BMW    1 Series  2011     premium unleaded (required)
# 3          3      BMW    1 Series  2011     premium unleaded (required)
# 4          4      BMW    1 Series  2011     premium unleaded (required)
# ...      ...      ...         ...   ...                             ...
# 11909  11909    Acura         ZDX  2012     premium unleaded (required)
# 11910  11910    Acura         ZDX  2012     premium unleaded (required)
# 11911  11911    Acura         ZDX  2012     premium unleaded (required)
# 11912  11912    Acura         ZDX  2013  premium unleaded (recommended)
# 11913  11913  Lincoln      Zephyr  2006                regular unleaded
#
#        Engine HP  Engine Cylinders Transmission Type      Driven_Wheels  \
# ...

# %%
#element-wise operations
df['Engine HP'] / 100
#pandas uses numpy, numpy acting on df series
# Out:
# 0        3.35
# 1        3.00
# 2        3.00
# 3        2.30
# 4        2.30
#          ...
# 11909    3.00
# 11910    3.00
# 11911    3.00
# 11912    3.00
# 11913    2.21
# Name: Engine HP, Length: 11914, dtype: float64

# %%
#filtering
df['Year'] >= 2015

#
df[
    df['Make'] == 'Nissan'
]
#
df[
    (df['Make'] == 'Nissan') & (df['Year'] >= 2015)
]

# %%
#String operations

'machine learning zoomcamp'.replace(' ', '_')

df['Vehicle_Style'].str.lower()

df['Vehicle_Style'] = df['Vehicle_Style'].str.replace(' ', '_').str.lower()

df

# %%
#Summarizing operations
#round doubles to nearest .00
df.describe().round(2)
# counts number of unique values 
df.nunique()
df.Make.nunique()
# missing values - find NaNs count in columns
df.isnull().sum() / df.isna().sum()
# replace NaNs with 0 or could be a string
df.fillna(0)
#describe - gets numeric columns, computes summary statistics
df.MSRP.describe()


#group by
df.groupby('Transmission Type').MSRP.max()
#SQL 
# SELECT 
#     transmission_type,
#     AVG(MSRP)
# FROM
#     cars
# GROUP BY
#     transmission_type

# %%
#Getting the NumPy arrays
#get array of a column's values
df.MSRP.values

#to make dictionary from arrays 
df.to_dict(orient='records')
